# %% [markdown]
# ### Projet de WebScrapping : Carte Interactive de la Satisfaction dans l'Hôtellerie et la Restauration

# %% [markdown]
# #### Scraping des données d'hôtels

# %% [markdown]
# ##### TripAdvisor

# %%
#pip install apify-client

# %%
from apify_client import ApifyClient

client = ApifyClient("apify_api_biqQYOhWEwWaZFC8HjsAiwt5St34tH1bpruh")

# Prepare the Actor input
run_input = {
    "startUrls": [{ "url": "https://www.tripadvisor.fr/Hotel_Review-g187147-d16711418-Reviews-Ibis_Styles_Paris_Meteor_Avenue_D_Italie-Paris_Ile_de_France.html" }],
    "maxItemsPerQuery": 20,
    "reviewRatings": ["ALL_REVIEW_RATINGS"],
    "reviewsLanguages": ["ALL_REVIEW_LANGUAGES"],
}

# Run the Actor and wait for it to finish
run = client.actor("maxcopell/tripadvisor-reviews").call(run_input=run_input)

# Fetch and print Actor results from the run's dataset (if there are any)
print("💾 Check your data here: https://console.apify.com/storage/datasets/" + run["defaultDatasetId"])
for item in client.dataset(run["defaultDatasetId"]).iterate_items():
    print(item)
# Out:
# 💾 Check your data here: https://console.apify.com/storage/datasets/68wZoGgfhog2MR6F9
# ...

# %%
import pandas as pd

# Ouvrir le fichier CSV en DataFrame
df = pd.read_csv("C:/Document/Christelle/S9/Webscraping and Applied ML/WebScrappingProject/dataset_tripadvisor-reviews_2024-12-13_15-44-55-203.csv")

# Afficher les premières lignes du DataFrame
df.head()
# Out:
#           id                                     title  rating  \
# 0  981570197  Fine for a short stay but avoid bar food       3
# 1  980466289                     Très bonne expérience       4
# 2  979522678             Fijn hotel met goed personeel       5
# 3  970794899                      Albergo consigliato        5
# 4  964120024                    Une très bonne adresse       5
#
#                                                 text travelDate  locationId  \
# 0  Modern, clean, nice bathrooms. Mattresses very...    2024-11    16711418
# 1  J'ai séjourné 3 nuits au sein de l'hôtel lors ...    2024-11    16711418
# 2  Twee kamers genomen. Uitstekend personeel. Zee...    2024-11    16711418
# 3  L'albergo ha camere per famiglie difficili da ...    2024-09    16711418
# 4  Hôtel tout à fait confortable, vraiment bien i...    2024-08    16711418
#
#                            placeInfo/address placeInfo/addressObj/city  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 42 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                20 non-null     int64
#  1   title                             20 non-null     object
#  2   rating                            20 non-null     int64
#  3   text                              20 non-null     object
#  4   travelDate                        20 non-null     object
#  5   locationId                        20 non-null     int64
#  6   placeInfo/address                 20 non-null     object
#  7   placeInfo/addressObj/city         20 non-null     object
#  8   placeInfo/addressObj/country      20 non-null     object
#  9   placeInfo/addressObj/postalcode   20 non-null     int64
#  10  placeInfo/addressObj/state        0 non-null      float64
#  11  placeInfo/addressObj/street1      20 non-null     object
# ...

# %% [markdown]
# #### Scraping des données de restauration

# %% [markdown]
# ##### Google Maps

# %%
from apify_client import ApifyClient

# Initialize the ApifyClient with your Apify API token
# Replace '<YOUR_API_TOKEN>' with your token.
client = ApifyClient("apify_api_biqQYOhWEwWaZFC8HjsAiwt5St34tH1bpruh")

# Prepare the Actor input
run_input = {
    "startUrls": [{ "url": "https://www.google.fr/maps/place/Bouillon+Pigalle/@48.8826552,2.3348886,17z/data=!3m1!4b1!4m6!3m5!1s0x47e66e45c7d2be55:0x6c3d2c3b62dc00e6!8m2!3d48.8826517!4d2.3374635!16s%2Fg%2F1ptw74zq7?hl=fr&entry=ttu&g_ep=EgoyMDI0MTIxMS4wIKXMDSoASAFQAw%3D%3D" }],
    "maxReviews": 50,
    "language": "fr",
}

# Run the Actor and wait for it to finish
run = client.actor("compass/google-maps-reviews-scraper").call(run_input=run_input)

# Fetch and print Actor results from the run's dataset (if there are any)
print("💾 Check your data here: https://console.apify.com/storage/datasets/" + run["defaultDatasetId"])
for item in client.dataset(run["defaultDatasetId"]).iterate_items():
    print(item)
# Out:
# 💾 Check your data here: https://console.apify.com/storage/datasets/30SbhcO1y4l5osYph
# ...

# %%
import pandas as pd

# Ouvrir le fichier CSV en DataFrame
df2 = pd.read_csv("C:/Document/Christelle/S9/Webscraping and Applied ML/WebScrappingProject/dataset_Google-Maps-Reviews-Scraper_2024-12-13_19-21-07-804.csv")

# Afficher les premières lignes du DataFrame
df2.head()
# Out:
#                                 address categories/0         categories/1  \
# 0  22 Bd de Clichy, 75018 Paris, France    Brasserie  Restaurant français
# 1  22 Bd de Clichy, 75018 Paris, France    Brasserie  Restaurant français
# 2  22 Bd de Clichy, 75018 Paris, France    Brasserie  Restaurant français
# 3  22 Bd de Clichy, 75018 Paris, France    Brasserie  Restaurant français
# 4  22 Bd de Clichy, 75018 Paris, France    Brasserie  Restaurant français
#
#   categoryName                  cid   city countryCode  \
# 0    Brasserie  7799438763248845030  Paris          FR
# 1    Brasserie  7799438763248845030  Paris          FR
# 2    Brasserie  7799438763248845030  Paris          FR
# 3    Brasserie  7799438763248845030  Paris          FR
# 4    Brasserie  7799438763248845030  Paris          FR
#
#                                      fid  \
# 0  0x47e66e45c7d2be55:0x6c3d2c3b62dc00e6
# 1  0x47e66e45c7d2be55:0x6c3d2c3b62dc00e6
# 2  0x47e66e45c7d2be55:0x6c3d2c3b62dc00e6
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 60 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   address                          50 non-null     object
#  1   categories/0                     50 non-null     object
#  2   categories/1                     50 non-null     object
#  3   categoryName                     50 non-null     object
#  4   cid                              50 non-null     int64
#  5   city                             50 non-null     object
#  6   countryCode                      50 non-null     object
#  7   fid                              50 non-null     object
#  8   imageUrl                         50 non-null     object
#  9   isAdvertisement                  50 non-null     bool
#  10  isLocalGuide                     50 non-null     bool
#  11  likesCount                       50 non-null     int64
# ...
